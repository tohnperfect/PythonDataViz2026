# %% [markdown]
# <a href="https://colab.research.google.com/github/tohnperfect/PythonDataViz2026/blob/main/HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ธนพงศ์ อินทระ

# %%
print('ID67xxxxxx1')
# Out:
# ID67xxxxxx1
